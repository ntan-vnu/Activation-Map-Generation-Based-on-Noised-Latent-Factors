# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ! ln -s /content/drive/MyDrive/datasets/BreakHis_v1 /content/drive/MyDrive/src/BreakHis_Activation-Map-Generation-Noised-Latent-Factors/datasets

# %%
! ln -s /content/drive/MyDrive/src/BreakHis_Activation-Map-Generation-Noised-Latent-Factors/ /content
# Out:
# ln: failed to create symbolic link '/content/BreakHis_Activation-Map-Generation-Noised-Latent-Factors': File exists

# %%
# %cd BreakHis_Activation-Map-Generation-Noised-Latent-Factors/
# Out:
# /content/drive/MyDrive/src/BreakHis_Activation-Map-Generation-Noised-Latent-Factors

# %%
! pip install tensorflow==2.15.1

# %% [markdown]
# # Initialization

# %%
# import tensorflow as tf
import numpy as np
import cv2
import glob
import pandas as pd
import matplotlib.pyplot as plt
import os

# print(tf.__version__)

# %%
import configs

# %%
import importlib
importlib.reload(configs)
print(dir(configs))
# Out:
# ['CGUNET_CHECKPOINT', 'CHECKPOINT_DIR', 'CLASS_NAMES', 'DATA_DIR', 'IMAGE_SIZE', 'NUM_CLASS', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %% [markdown]
# # Classification-Guided UNet (CGUNet)

# %%
def double_conv_block(x, n_filters):
    x = tf.keras.layers.Conv2D(n_filters, 3, padding="same",
                        activation="relu", kernel_initializer="he_normal")(x)
    x = tf.keras.layers.Conv2D(n_filters, 3, padding="same", activation="relu",
                        kernel_initializer="he_normal")(x)
    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = tf.keras.layers.MaxPool2D(2)(f)
    p = tf.keras.layers.Dropout(0.5)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    x = tf.keras.layers.concatenate([x, conv_features])
    x = tf.keras.layers.Dropout(0.5)(x)
    x = double_conv_block(x, n_filters)
    return x

def build_unet_model(input_shape, name):
    inputs = tf.keras.layers.Input(shape=input_shape)

    f1, p1 = downsample_block(inputs, 64)
    f2, p2 = downsample_block(p1, 128)
    f3, p3 = downsample_block(p2, 256)

    bottleneck = double_conv_block(p3, 512)

    u7 = upsample_block(bottleneck, f3, 256)
    u8 = upsample_block(u7, f2, 128)
    u9 = upsample_block(u8, f1, 64)

    # outputs_img
    outputs_img = tf.keras.layers.Conv2D(3, 1, padding="same",
                            activation = "sigmoid", name="out_img")(u9)

    # outputs_class
    gap = tf.keras.layers.GlobalAveragePooling2D()(bottleneck)
    d1 = tf.keras.layers.Dense(256, activation='sigmoid')(gap)
    drop1 = tf.keras.layers.Dropout(0.5)(d1)
    d2 = tf.keras.layers.Dense(64, activation='sigmoid')(drop1)
    drop2 = tf.keras.layers.Dropout(0.5)(d2)
    d3 = tf.keras.layers.Dense(configs.NUM_CLASS, activation='sigmoid')(drop2)
    outputs_class = tf.keras.layers.Softmax(name="out_class")(d3)

    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs=[outputs_img, outputs_class],
                                name=name)

    return unet_model

# %%
model = build_unet_model(configs.IMAGE_SIZE, "CGUNet")
model.summary()
# Out:
# Model: "CGUNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_22 (Conv2D)          (None, 256, 256, 64)         1792      ['input_3[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_22[0][0]']
#
#  max_pooling2d_6 (MaxPoolin  (None, 128, 128, 64)         0         ['conv2d_23[0][0]']
#  g2D)
#
#  dropout_11 (Dropout)        (None, 128, 128, 64)         0         ['max_pooling2d_6[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 128)        73856     ['dropout_11[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_24[0][0]']
#
#  max_pooling2d_7 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_25[0][0]']
#  g2D)
#
#  dropout_12 (Dropout)        (None, 64, 64, 128)          0         ['max_pooling2d_7[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 256)          295168    ['dropout_12[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_26[0][0]']
#
#  max_pooling2d_8 (MaxPoolin  (None, 32, 32, 256)          0         ['conv2d_27[0][0]']
#  g2D)
#
#  dropout_13 (Dropout)        (None, 32, 32, 256)          0         ['max_pooling2d_8[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 32, 32, 512)          1180160   ['dropout_13[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_28[0][0]']
#
#  conv2d_transpose_4 (Conv2D  (None, 64, 64, 256)          1179904   ['conv2d_29[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 64, 64, 512)          0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'conv2d_27[0][0]']
#
#  dropout_14 (Dropout)        (None, 64, 64, 512)          0         ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 256)          1179904   ['dropout_14[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_30[0][0]']
#
#  conv2d_transpose_5 (Conv2D  (None, 128, 128, 128)        295040    ['conv2d_31[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 128, 128, 256)        0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'conv2d_25[0][0]']
#
#  dropout_15 (Dropout)        (None, 128, 128, 256)        0         ['concatenate_4[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 128, 128, 128)        295040    ['dropout_15[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_32[0][0]']
#
#  global_average_pooling2d_1  (None, 512)                  0         ['conv2d_29[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_transpose_6 (Conv2D  (None, 256, 256, 64)         73792     ['conv2d_33[0][0]']
#  Transpose)
#
#  dense_3 (Dense)             (None, 256)                  131328    ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  concatenate_5 (Concatenate  (None, 256, 256, 128)        0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'conv2d_23[0][0]']
#
#  dropout_17 (Dropout)        (None, 256)                  0         ['dense_3[0][0]']
#
#  dropout_16 (Dropout)        (None, 256, 256, 128)        0         ['concatenate_5[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   16448     ['dropout_17[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 256, 256, 64)         73792     ['dropout_16[0][0]']
#
#  dropout_18 (Dropout)        (None, 64)                   0         ['dense_4[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_34[0][0]']
#
#  dense_5 (Dense)             (None, 8)                    520       ['dropout_18[0][0]']
#
#  out_img (Conv2D)            (None, 256, 256, 3)          195       ['conv2d_35[0][0]']
#
#  out_class (Softmax)         (None, 8)                    0         ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 8705931 (33.21 MB)
# Trainable params: 8705931 (33.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=1e-4),
              loss={'out_img':tf.losses.MeanSquaredError(),
                      'out_class':tf.losses.CategoricalCrossentropy()},
              metrics={'out_class':'accuracy'})

# %% [markdown]
# # Training

# %%
class MyDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, data_dir, subsets_csv, subset,
                       batch_size=32, shuffle=True):
        self.data_dir = data_dir
        self.subsets_csv = subsets_csv
        self.subset = subset
        self.batch_size = batch_size
        self.shuffle = shuffle

        self.filenames = None
        self.load()
        self.indices = None
        self.on_epoch_end()

    def load(self):
        df = pd.read_csv(self.subsets_csv)
        self.filenames = df[df['grp'] == self.subset
                            ]['filename'].tolist()
        self.filenames = [os.path.join(self.data_dir, it)
                          for it in self.filenames]
        print(len(self.filenames), 'images found')
        print(self.filenames[0])

    def __len__(self):
        return int(np.ceil(len(self.filenames) / self.batch_size))

    def __getitem__(self, index):
        indices = self.indices[index*self.batch_size:(index+1)*self.batch_size]
        filenames = [self.filenames[k] for k in indices]
        X, Y = self.__data_generation(filenames)
        return X, Y

    def on_epoch_end(self):
        self.indices = np.arange(len(self.filenames))
        if self.shuffle == True:
            np.random.shuffle(self.indices)

    def filename2onehot(self, fn):
        for i, classname in enumerate(configs.CLASS_NAMES):
            if classname in fn:
                result = np.zeros(configs.NUM_CLASS, dtype=np.float64)
                result[i] = 1
                return result
        return None

    def __data_generation(self, filenames):
        num = len(filenames)
        X = np.empty([num, *configs.IMAGE_SIZE], dtype=np.float64)
        Y_class = np.empty([num, configs.NUM_CLASS])
        for i, fn in enumerate(filenames):
            img = cv2.imread(fn)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            delta = (configs.IMAGE_SIZE[1] - configs.IMAGE_SIZE[0]) // 2
            img = img[:, delta:configs.IMAGE_SIZE[1]-delta-1]
            img = cv2.resize(img, configs.IMAGE_SIZE[:2])
            X[i] = np.array(img, dtype=np.float64) / 255.
            Y_class[i] = self.filename2onehot(fn)

        return X, {'out_img':X, 'out_class':Y_class}

# %%
train_datagen = MyDataGenerator(configs.DATA_DIR,
                                configs.DATA_DIR+'/subsets.csv',
                                'train', shuffle=True)
val_datagen = MyDataGenerator(configs.DATA_DIR,
                                configs.DATA_DIR+'/subsets.csv',
                                'val', shuffle=False)
test_datagen = MyDataGenerator(configs.DATA_DIR,
                                configs.DATA_DIR+'/subsets.csv',
                                'test', shuffle=False)
# Out:
# 4000 images found
# datasets/BreakHis_v1/malignant/SOB/mucinous_carcinoma/SOB_M_MC_14-12773/40X/SOB_M_MC-14-12773-40-021.png
# 1000 images found
# datasets/BreakHis_v1/benign/SOB/fibroadenoma/SOB_B_F_14-14134/40X/SOB_B_F-14-14134-40-003.png
# 2909 images found
# datasets/BreakHis_v1/malignant/SOB/lobular_carcinoma/SOB_M_LC_14-15570C/100X/SOB_M_LC-14-15570C-100-005.png

# %%
X, Ys = train_datagen[0]

# %%
print(X.shape)
plt.imshow((X[0]*255).astype(np.uint8))
plt.show()
# Out:
# (32, 256, 256, 3)

# %%
Ys.keys()
# Out:
# dict_keys(['out_img', 'out_class'])

# %%
cb_early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=1e-4,
    patience=8,
    verbose=1,
    mode='auto'
)
cb_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    configs.CHECKPOINT_DIR + '/' + model.name,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    mode='auto'
)
cb_reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    verbose=1,
    mode='auto',
    min_delta=1e-4,
    min_lr=0
)
callbacks = [cb_model_checkpoint,
             cb_reduce_lr,
             cb_early_stop]

# %%
history = model.fit_generator(train_datagen,
                    epochs=2024,
                    verbose=1,
                    callbacks=callbacks,
                    validation_data=val_datagen)
# Out:
# <ipython-input-30-d083b1b0c3f0>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(train_datagen,
# Epoch 1/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.9899 - out_img_loss: 0.0171 - out_class_loss: 1.9728 - out_class_accuracy: 0.3582
# Epoch 1: val_loss improved from inf to 1.93457, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 2120s 17s/step - loss: 1.9899 - out_img_loss: 0.0171 - out_class_loss: 1.9728 - out_class_accuracy: 0.3582 - val_loss: 1.9346 - val_out_img_loss: 0.0059 - val_out_class_loss: 1.9286 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 2/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.9225 - out_img_loss: 0.0057 - out_class_loss: 1.9168 - out_class_accuracy: 0.4383
# Epoch 2: val_loss improved from 1.93457 to 1.90415, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 243s 2s/step - loss: 1.9225 - out_img_loss: 0.0057 - out_class_loss: 1.9168 - out_class_accuracy: 0.4383 - val_loss: 1.9041 - val_out_img_loss: 0.0035 - val_out_class_loss: 1.9006 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 3/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8941 - out_img_loss: 0.0042 - out_class_loss: 1.8899 - out_class_accuracy: 0.4430
# Epoch 3: val_loss improved from 1.90415 to 1.88273, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 237s 2s/step - loss: 1.8941 - out_img_loss: 0.0042 - out_class_loss: 1.8899 - out_class_accuracy: 0.4430 - val_loss: 1.8827 - val_out_img_loss: 0.0040 - val_out_class_loss: 1.8787 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 4/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8802 - out_img_loss: 0.0039 - out_class_loss: 1.8764 - out_class_accuracy: 0.4455
# Epoch 4: val_loss improved from 1.88273 to 1.87040, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 233s 2s/step - loss: 1.8802 - out_img_loss: 0.0039 - out_class_loss: 1.8764 - out_class_accuracy: 0.4455 - val_loss: 1.8704 - val_out_img_loss: 0.0036 - val_out_class_loss: 1.8668 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 5/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8606 - out_img_loss: 0.0034 - out_class_loss: 1.8572 - out_class_accuracy: 0.4523
# Epoch 5: val_loss did not improve from 1.87040
# 125/125 [==============================] - 229s 2s/step - loss: 1.8606 - out_img_loss: 0.0034 - out_class_loss: 1.8572 - out_class_accuracy: 0.4523 - val_loss: 1.8787 - val_out_img_loss: 0.0023 - val_out_class_loss: 1.8764 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 6/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8577 - out_img_loss: 0.0031 - out_class_loss: 1.8546 - out_class_accuracy: 0.4518
# Epoch 6: val_loss improved from 1.87040 to 1.84180, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 233s 2s/step - loss: 1.8577 - out_img_loss: 0.0031 - out_class_loss: 1.8546 - out_class_accuracy: 0.4518 - val_loss: 1.8418 - val_out_img_loss: 0.0026 - val_out_class_loss: 1.8392 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 7/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8298 - out_img_loss: 0.0027 - out_class_loss: 1.8272 - out_class_accuracy: 0.4790
# Epoch 7: val_loss improved from 1.84180 to 1.83071, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 232s 2s/step - loss: 1.8298 - out_img_loss: 0.0027 - out_class_loss: 1.8272 - out_class_accuracy: 0.4790 - val_loss: 1.8307 - val_out_img_loss: 0.0022 - val_out_class_loss: 1.8285 - val_out_class_accuracy: 0.4750 - lr: 1.0000e-04
# Epoch 8/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8175 - out_img_loss: 0.0025 - out_class_loss: 1.8150 - out_class_accuracy: 0.4893
# Epoch 8: val_loss improved from 1.83071 to 1.81906, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 232s 2s/step - loss: 1.8175 - out_img_loss: 0.0025 - out_class_loss: 1.8150 - out_class_accuracy: 0.4893 - val_loss: 1.8191 - val_out_img_loss: 0.0049 - val_out_class_loss: 1.8142 - val_out_class_accuracy: 0.4900 - lr: 1.0000e-04
# Epoch 9/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8108 - out_img_loss: 0.0027 - out_class_loss: 1.8081 - out_class_accuracy: 0.4980
# Epoch 9: val_loss did not improve from 1.81906
# 125/125 [==============================] - 227s 2s/step - loss: 1.8108 - out_img_loss: 0.0027 - out_class_loss: 1.8081 - out_class_accuracy: 0.4980 - val_loss: 1.8440 - val_out_img_loss: 0.0029 - val_out_class_loss: 1.8411 - val_out_class_accuracy: 0.4290 - lr: 1.0000e-04
# Epoch 10/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8230 - out_img_loss: 0.0031 - out_class_loss: 1.8200 - out_class_accuracy: 0.4750
# Epoch 10: val_loss improved from 1.81906 to 1.81433, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 230s 2s/step - loss: 1.8230 - out_img_loss: 0.0031 - out_class_loss: 1.8200 - out_class_accuracy: 0.4750 - val_loss: 1.8143 - val_out_img_loss: 0.0018 - val_out_class_loss: 1.8125 - val_out_class_accuracy: 0.4810 - lr: 1.0000e-04
# Epoch 11/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8051 - out_img_loss: 0.0026 - out_class_loss: 1.8025 - out_class_accuracy: 0.4972
# Epoch 11: val_loss improved from 1.81433 to 1.80625, saving model to checkpoints/CGUNet
# 125/125 [==============================] - 230s 2s/step - loss: 1.8051 - out_img_loss: 0.0026 - out_class_loss: 1.8025 - out_class_accuracy: 0.4972 - val_loss: 1.8062 - val_out_img_loss: 0.0036 - val_out_class_loss: 1.8026 - val_out_class_accuracy: 0.4960 - lr: 1.0000e-04
# Epoch 12/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8436 - out_img_loss: 0.0030 - out_class_loss: 1.8407 - out_class_accuracy: 0.4475
# Epoch 12: val_loss did not improve from 1.80625
# 125/125 [==============================] - 225s 2s/step - loss: 1.8436 - out_img_loss: 0.0030 - out_class_loss: 1.8407 - out_class_accuracy: 0.4475 - val_loss: 1.8656 - val_out_img_loss: 0.0018 - val_out_class_loss: 1.8638 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 13/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8457 - out_img_loss: 0.0020 - out_class_loss: 1.8436 - out_class_accuracy: 0.4450
# Epoch 13: val_loss did not improve from 1.80625
# 125/125 [==============================] - 225s 2s/step - loss: 1.8457 - out_img_loss: 0.0020 - out_class_loss: 1.8436 - out_class_accuracy: 0.4450 - val_loss: 1.8642 - val_out_img_loss: 0.0020 - val_out_class_loss: 1.8622 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 14/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8429 - out_img_loss: 0.0018 - out_class_loss: 1.8412 - out_class_accuracy: 0.4450
# Epoch 14: val_loss did not improve from 1.80625
# 125/125 [==============================] - 225s 2s/step - loss: 1.8429 - out_img_loss: 0.0018 - out_class_loss: 1.8412 - out_class_accuracy: 0.4450 - val_loss: 1.8630 - val_out_img_loss: 0.0019 - val_out_class_loss: 1.8611 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 15/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8415 - out_img_loss: 0.0016 - out_class_loss: 1.8399 - out_class_accuracy: 0.4450
# Epoch 15: val_loss did not improve from 1.80625
# 125/125 [==============================] - 232s 2s/step - loss: 1.8415 - out_img_loss: 0.0016 - out_class_loss: 1.8399 - out_class_accuracy: 0.4450 - val_loss: 1.8622 - val_out_img_loss: 0.0022 - val_out_class_loss: 1.8600 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 16/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8383 - out_img_loss: 0.0015 - out_class_loss: 1.8369 - out_class_accuracy: 0.4450
# Epoch 16: val_loss did not improve from 1.80625
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 125/125 [==============================] - 226s 2s/step - loss: 1.8383 - out_img_loss: 0.0015 - out_class_loss: 1.8369 - out_class_accuracy: 0.4450 - val_loss: 1.8612 - val_out_img_loss: 0.0020 - val_out_class_loss: 1.8592 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-04
# Epoch 17/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8389 - out_img_loss: 0.0014 - out_class_loss: 1.8375 - out_class_accuracy: 0.4450
# Epoch 17: val_loss did not improve from 1.80625
# 125/125 [==============================] - 225s 2s/step - loss: 1.8389 - out_img_loss: 0.0014 - out_class_loss: 1.8375 - out_class_accuracy: 0.4450 - val_loss: 1.8613 - val_out_img_loss: 0.0022 - val_out_class_loss: 1.8591 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-05
# Epoch 18/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8400 - out_img_loss: 0.0014 - out_class_loss: 1.8386 - out_class_accuracy: 0.4450
# Epoch 18: val_loss did not improve from 1.80625
# 125/125 [==============================] - 226s 2s/step - loss: 1.8400 - out_img_loss: 0.0014 - out_class_loss: 1.8386 - out_class_accuracy: 0.4450 - val_loss: 1.8612 - val_out_img_loss: 0.0022 - val_out_class_loss: 1.8590 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-05
# Epoch 19/2024
# 125/125 [==============================] - ETA: 0s - loss: 1.8382 - out_img_loss: 0.0014 - out_class_loss: 1.8368 - out_class_accuracy: 0.4450
# Epoch 19: val_loss did not improve from 1.80625
# 125/125 [==============================] - 226s 2s/step - loss: 1.8382 - out_img_loss: 0.0014 - out_class_loss: 1.8368 - out_class_accuracy: 0.4450 - val_loss: 1.8612 - val_out_img_loss: 0.0022 - val_out_class_loss: 1.8590 - val_out_class_accuracy: 0.4170 - lr: 1.0000e-05
# Epoch 19: early stopping

# %%
pd.DataFrame.from_dict(history.history) \
           .to_csv(configs.CHECKPOINT_DIR + '/' + model.name +
                   '/history_cgunet.csv', index=False)

# %%
df = pd.read_csv(configs.CGUNET_CHECKPOINT +
                 '/history_cgunet.csv')

# plt.subplot(5, 1, 1)
plt.plot(df['loss'], label='loss')
plt.plot(df['val_loss'], label='val_loss')
plt.legend()
plt.title('loss')
plt.xticks([0, 5, 10, 15], [0, 5, 10, 15])
plt.show()

# plt.subplot(5, 1, 2)
plt.plot(df['out_img_loss'], label='out_img_loss')
plt.plot(df['val_out_img_loss'], label='val_out_img_loss')
plt.legend()
plt.title('out_img_loss')
plt.show()

# plt.subplot(5, 1, 3)
plt.plot(df['out_class_loss'], label='class_loss')
plt.plot(df['val_out_class_loss'], label='val_class_loss')
plt.legend()
plt.xticks([0, 5, 10, 15], [0, 5, 10, 15])
plt.title('class_loss')
plt.show()

# plt.subplot(5, 1, 4)
plt.plot(df['out_class_accuracy'], label='out_class_accuracy')
plt.plot(df['val_out_class_accuracy'], label='val_out_class_accuracy')
plt.legend()
plt.title('out_class_accuracy')
plt.ylim(0, 1)
plt.show()

# plt.subplot(5, 1, 5)
plt.plot(df['lr'], label='lr')
plt.legend()
plt.title('lr')
plt.show()

# plt.legend()
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Evaluation

# %%
model = tf.keras.models.load_model(configs.CGUNET_CHECKPOINT)
model.evaluate_generator(train_datagen, verbose=1)
model.evaluate_generator(val_datagen, verbose=1)
model.evaluate_generator(test_datagen, verbose=1)
# Out:
# <ipython-input-37-d69e0a226257>:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(train_datagen, verbose=1)
# 125/125 [==============================] - 54s 422ms/step - loss: 1.7823 - out_img_loss: 0.0037 - out_class_loss: 1.7786 - out_class_accuracy: 0.5163
# <ipython-input-37-d69e0a226257>:3: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(val_datagen, verbose=1)
# 32/32 [==============================] - 13s 403ms/step - loss: 1.8062 - out_img_loss: 0.0036 - out_class_loss: 1.8026 - out_class_accuracy: 0.4960
# <ipython-input-37-d69e0a226257>:4: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(test_datagen, verbose=1)
# 91/91 [==============================] - 1299s 14s/step - loss: 1.7988 - out_img_loss: 0.0037 - out_class_loss: 1.7952 - out_class_accuracy: 0.5009
# [1.7988429069519043,
#  0.0036612641997635365,
#  1.7951819896697998,
#  0.5008593797683716]

# %%
plt.subplot(4, 1, 1)
plt.bar(['train', 'val', 'test'], [1.7823, 1.8062, 1.7988]) # loss
plt.title('loss')
plt.subplot(4, 1, 2)
plt.bar(['train', 'val', 'test'], [0.0037, 0.0036, 0.0037]) # out_img_loss
plt.title('out_img_loss')
plt.subplot(4, 1, 3)
plt.bar(['train', 'val', 'test'], [1.7786, 1.8026, 1.7952]) # out_class_loss
plt.title('out_class_loss')
plt.subplot(4, 1, 4)
plt.bar(['train', 'val', 'test'], [0.5163, 0.4960, 0.5009]) # accuracy
plt.title('accuracy')
plt.tight_layout()
plt.show()

# %%
Xs, Ys = val_datagen[0]
print(Xs.shape, Ys.keys())
# Out:
# (32, 256, 256, 3) dict_keys(['out_img', 'out_class'])

# %%
Y_s = model.predict(Xs)
# Out:
# 1/1 [==============================] - 0s 296ms/step

# %%
decoded_imgs = Y_s[0]
print(decoded_imgs.shape)
# Out:
# (32, 256, 256, 3)

# %%
def toRGB(img):
  img = np.array(img * 255, dtype=np.uint8)
  return img

for i in range(16):
  plt.subplot(4, 4, i+1)
  if i % 2 == 0:
    plt.imshow(toRGB(Xs[i]))
    # plt.title('original')
  else:
    plt.imshow(toRGB(decoded_imgs[i-1]))
    # plt.title('decoded')
  plt.axis('off')

plt.tight_layout()
plt.show()
